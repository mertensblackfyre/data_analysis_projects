# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid = pd.read_csv("compact.csv", sep=None, engine='python')
covid.shape
covid.loc[:100]
# Out:
#          country        date  total_cases  new_cases  new_cases_smoothed  \
# 0    Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1    Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2    Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3    Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4    Afghanistan  2020-01-05          0.0        0.0                 NaN
# ..           ...         ...          ...        ...                 ...
# 96   Afghanistan  2020-04-06        299.0       25.0           27.571428
# 97   Afghanistan  2020-04-07        337.0       38.0           31.857143
# 98   Afghanistan  2020-04-08        367.0       30.0           28.714285
# 99   Afghanistan  2020-04-09        423.0       56.0           33.000000
# 100  Afghanistan  2020-04-10        444.0       21.0           35.714287
#
#      total_cases_per_million  new_cases_per_million  \
# ...

# %%
 covid.isnull().sum()
# Out:
# country                            0
# date                               0
# total_cases                    12348
# new_cases                      16288
# new_cases_smoothed             17497
#                                ...
# extreme_poverty               204429
# diabetes_prevalence            90733
# handwashing_facilities        293379
# hospital_beds_per_thousand    182269
# human_development_index       570606
# Length: 61, dtype: int64

# %%
covid.dropna(how="all")
# Out:
#             country        date  total_cases  new_cases  new_cases_smoothed  \
# 0       Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1       Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2       Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3       Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4       Afghanistan  2020-01-05          0.0        0.0                 NaN
# ...             ...         ...          ...        ...                 ...
# 570601     Zimbabwe  2026-02-18     266436.0        0.0                 0.0
# 570602     Zimbabwe  2026-02-19     266436.0        0.0                 0.0
# 570603     Zimbabwe  2026-02-20     266436.0        0.0                 0.0
# 570604     Zimbabwe  2026-02-21     266436.0        0.0                 0.0
# 570605     Zimbabwe  2026-02-22     266436.0        0.0                 0.0
#
# ...

# %%
covid.columns.tolist()
# Out:
# ['country',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'excess_mortality',
#  'excess_mortality_cumulative',
#  'excess_mortality_cumulative_absolute',
#  'excess_mortality_cumulative_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'icu_patients',
#  'icu_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'stringency_index',
#  'reproduction_rate',
#  'total_tests',
#  'new_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'total_vaccinations',
# ...

# %%
covid.drop(columns=[ 'new_deaths_per_million',
 'new_deaths_smoothed_per_million',
 'excess_mortality',
 'excess_mortality_cumulative',
 'excess_mortality_cumulative_absolute',
 'excess_mortality_cumulative_per_million',
 'hosp_patients',
 'hosp_patients_per_million',
 'weekly_hosp_admissions',
 'weekly_hosp_admissions_per_million',
 'icu_patients',
 'icu_patients_per_million','weekly_icu_admissions_per_million',
 'stringency_index',
 'reproduction_rate',
 'total_tests',
 'new_tests',
 'total_tests_per_thousand',
 'new_tests_per_thousand',
 'new_tests_smoothed',
 'new_tests_smoothed_per_thousand',
 'positive_rate',
 'tests_per_case',
 'total_vaccinations',
 'people_vaccinated',
 'people_fully_vaccinated',
 'total_boosters',
 'new_vaccinations',
 'new_vaccinations_smoothed',
 'total_vaccinations_per_hundred',
 'people_vaccinated_per_hundred',
 'people_fully_vaccinated_per_hundred',
 'total_boosters_per_hundred',
 'new_vaccinations_smoothed_per_million',
 'new_people_vaccinated_smoothed',
 'new_people_vaccinated_smoothed_per_hundred',], inplace=True)

# %%
covid.columns.tolist()
# Out:
# ['country',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_deaths_per_million',
#  'weekly_icu_admissions',
#  'code',
#  'continent',
#  'population',
#  'population_density',
#  'median_age',
#  'life_expectancy',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'diabetes_prevalence',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'human_development_index']

# %%
covid.drop(columns=['weekly_icu_admissions', 'new_deaths_smoothed', 'new_cases_per_million',
 'new_cases_smoothed_per_million', 'new_cases_smoothed'],inplace=True)

# %%
covid.columns.tolist()
# Out:
# ['country',
#  'date',
#  'total_cases',
#  'new_cases',
#  'total_cases_per_million',
#  'total_deaths',
#  'new_deaths',
#  'total_deaths_per_million',
#  'code',
#  'continent',
#  'population',
#  'population_density',
#  'median_age',
#  'life_expectancy',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'diabetes_prevalence',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'human_development_index']

# %%
a = covid.groupby(["continent"]).sum()
col = a.index.tolist()
def drop_continents_from_country_column(rows):
    if rows["country"] in col:
        rows.drop(index=rows["country"],axis="index")
    return rows["country"]

rows["country"] = covid.apply(drop_continents_from_country_column,axis="columns")
# Out:
# Africa
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 9
#       6         rows.drop(index=rows["country"],axis="index")
#       7     return rows["country"]
# ----> 9 rows["country"] = covid.apply(drop_continents_from_country_column,axis="columns")
#
# File /nix/store/c7crqc6m3idh9wm61kak07b7xycabwpv-python3.13-pandas-2.3.3/lib/python3.13/site-packages/pandas/core/frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# ...
