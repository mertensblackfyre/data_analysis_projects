# %%
import pandas as pd
import numpy as np

# %%
fifa = pd.read_csv("fifa21 raw data v2.csv",low_memory=False)

# %%
# Percentage of NaNs for each column
total_cells = np.prod(fifa.shape)
total_missing = fifa.isnull().sum()
miss = (total_missing/total_cells) * 100
print(miss)
# Out:
# ID           0.000000
# Name         0.000000
# LongName     0.000000
# photoUrl     0.000000
# playerUrl    0.000000
#                ...
# PAS          0.000000
# DRI          0.000000
# DEF          0.000000
# PHY          0.000000
# Hits         0.177572
# Length: 77, dtype: float64

# %%
# Replace all NaNs in Hits with 0
fifa["Hits"] = fifa["Hits"].bfill(axis=0).fillna(0)

# %%
# Change Wage from string literal to Number
def wages_num(rows):
    n = len(rows["Wage"])
    last = rows["Wage"][n-1]
    num = 0
    try:
      num = int(float(rows["Wage"][1:n-1]))
    except ValueError:
        num = int(rows["Wage"][1:n])
       
    if last == "K":
        num = num * 1000
    if last == "M":
        num = num * 1000000
        
    rows["Wage"] = num
    return rows["Wage"] 

# Insert a new column for the new Wage numbers
new_wage_col = fifa.apply(wages_num, axis="columns")
fifa.insert(loc=22, column='Wage Number', value=new_wage_col)

# %%
# Change Values from string literal to Number
def value_num(rows):
    n = len(rows["Value"])
    last = rows["Value"][n-1]
    num = 0
    try:
      num = int(float(rows["Value"][1:n-1]))
    except ValueError:
        num = int(rows["Value"][1:n])
       
    if last == "K":
        num = num * 1000
    if last == "M":
        num = num * 1000000
        
    rows["Value"] = num
    return rows["Value"] 
# Insert a new column for the new Value numbers    
new_value_col = fifa.apply(value_num, axis="columns")
fifa.insert(loc=21, column='Value Number', value=new_value_col)

# %%
# Remove "\n" from the "Club" column
def remove_space(rows):
    return rows["Club"].strip()

fifa["Club"] = fifa.apply(remove_space, axis="columns")

# %%
# Remove "*" from the "IR" column
def remove_star(rows):
    x = rows["IR"].replace("★",'')
    return int(x)

fifa["IR"] = fifa.apply(remove_star, axis="columns")

# %%
# Rename ↓OVA Column to OVA
fifa.rename(columns={"↓OVA":"OVA"},inplace=True)
# Create a sub DataFrame
sub_fifa = fifa[["ID","Name","Nationality","OVA","Club","Value","Value Number","Wage","Wage Number"]]

# %%
# Top 10 rated players
top_rated_players = sub_fifa.sort_values(by="OVA",ascending=False)[:10]
# Highest paid players
highest_paid_players= sub_fifa.sort_values(by="Wage Number",ascending=False)[:20]
# Most Valued players
most_valued_players= sub_fifa.sort_values(by="Value Number",ascending=False)[:20]

# %%
highest_paid_players
#top_rated_players
# Out:
#         ID             Name Nationality  OVA                 Club    Value  \
# 0   158023         L. Messi   Argentina   93         FC Barcelona  €103.5M
# 3   192985     K. De Bruyne     Belgium   91      Manchester City    €129M
# 26  183277        E. Hazard     Belgium   88          Real Madrid   €89.5M
# 15  165153       K. Benzema      France   89          Real Madrid   €83.5M
# 27  182521         T. Kroos     Germany   88          Real Madrid   €87.5M
# 12  200145         Casemiro      Brazil   89          Real Madrid   €90.5M
# 16  155862     Sergio Ramos       Spain   89          Real Madrid   €33.5M
# 17  153079        S. Agüero   Argentina   89      Manchester City   €83.5M
# 28  194765     A. Griezmann      France   87         FC Barcelona   €79.5M
# 4   190871        Neymar Jr      Brazil   91  Paris Saint-Germain    €132M
# 18  202652      R. Sterling     England   88      Manchester City  €114.5M
# 9   192448    M. ter Stegen     Germany   90         FC Barcelona    €110M
# 44  177003        L. Modrić     Croatia   87          Real Madrid   €36.5M
# 11  208722          S. Mané     Senegal   90            Liverpool  €120.5M
# 13  192119      T. Courtois     Belgium   89          Real Madrid     €82M
# 6   209331         M. Salah       Egypt   90            Liverpool  €120.5M
# 40  189511  Sergio Busquets       Spain   87         FC Barcelona     €56M
# 5   188545   R. Lewandowski      Poland   91    FC Bayern München    €111M
# 50  204963         Carvajal       Spain   86          Real Madrid   €61.5M
# 31  218667   Bernardo Silva    Portugal   87      Manchester City     €95M
#
#     Value Number   Wage  Wage Number
# 0      103000000  €560K       560000
# 3      129000000  €370K       370000
# 26      89000000  €350K       350000
# 15      83000000  €350K       350000
# 27      87000000  €310K       310000
# 12      90000000  €310K       310000
# 16      33000000  €300K       300000
# 17      83000000  €300K       300000
# 28      79000000  €290K       290000
# 4      132000000  €270K       270000
# 18     114000000  €270K       270000
# 9      110000000  €260K       260000
# 44      36000000  €260K       260000
# 11     120000000  €250K       250000
# 13      82000000  €250K       250000
# 6      120000000  €250K       250000
# 40      56000000  €240K       240000
# 5      111000000  €240K       240000
# 50      61000000  €230K       230000
# 31      95000000  €230K       230000
