# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"key1" : ["a", "a",None, "b", "b", "a", None],
                   "key2" : pd.Series([1, 2, 1, 2, 1, None, 1], dtype="Int64"),
                   "data1" : np.random.standard_normal(7),
                   "data2" : np.random.standard_normal(7)})
states = np.array(["OH", "CA", "CA", "OH", "OH", "CA", "OH"])

# DataFrame for dictionary and function mapping
people = pd.DataFrame(np.random.standard_normal((5, 5)),
                      columns=["a", "b", "c", "d", "e"],
                      index=["Joe", "Steve", "Wanda", "Jill", "Trey"])

# %%
grouped = df["data1"].groupby(df["key1"])
#grouped.mean()

grouped.apply(lambda x: x.to_dict()).dropna()
#grouped.groupby(grouped.index).apply(list)
# Out:
# key1
# a     0   -0.278201
#       1    1.062962
#       5   -0.756454
# b     3   -1.029528
#       4    0.640485
# Name: data1, dtype: float64

# %%
df
# Out:
#    key1  key2     data1     data2
# 0     a     1 -0.278201  2.940753
# 1     a     2  1.062962  0.641572
# 2  None     1  1.502691 -0.635489
# 3     b     2 -1.029528 -0.901494
# 4     b     1  0.640485  1.392954
# 5     a  <NA> -0.756454  1.006292
# 6  None     1 -0.811412 -0.342241

# %%
means = df["data1"].groupby([df["key1"], df["key2"]]).mean()
means.unstack()

#means.apply(dict)
# Out:
# key2         1         2
# key1
# a    -0.278201  1.062962
# b     0.640485 -1.029528
