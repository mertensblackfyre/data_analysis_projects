# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Load any image
img = Image.open("l.jpg")
img_array = np.array(img)



R = img_array[:,:,0] / 255
G = img_array[:,:,1] / 255
B = img_array[:,:,2] / 255
C = R + G + B


#C1 = (C <= 0.0031308)

#C2 = (C > 0.0031308)
np.where(C > 0.0031308, img_array, 1.055 * (C ** (1/2.4)) - 0.055)
print(gre)
# See what it actually is
#print(img_array.shape)  # (height, width, 3) for RGB
#print(img_array)
#print(img_array.shape)  # (height, width, 3) for RGB
#print(img_array.dtype)  # uint8 (0-255)

#plt.imshow(img_array)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 20
#      14 C = R + G + B
#      17 #C1 = (C <= 0.0031308)
#      18
#      19 #C2 = (C > 0.0031308)
# ---> 20 np.where(C > 0.0031308, img_array, 1.055 * (C ** (1/2.4)) - 0.055)
#      21 print(gre)
#      22 # See what it actually is
#      23 #print(img_array.shape)  # (height, width, 3) for RGB
#      24 #print(img_array)
#    (...)     28 #plt.imshow(img_array)
#      29 #plt.show()
#
# ValueError: operands could not be broadcast together with shapes (736,736) (736,736,3) (736,736)

# %% [markdown]
# #### tmp = np.array([[[ 1, 2, 3],
#  #[ 4, 5, 6],[89,12,2]],
#  #[[ 7, 8, 9],[1,2,3],
#  [10, 11, 12]]])
