# %%
import numpy as np
from numpy.linalg import det

# %%
# Out:
# [[3 1]
#  [4 2]]
# [ 7 10]

# %%
i_hat = np.array([2,0])
j_hat = np.array([0,1.5])!

m = np.array([i_hat,j_hat]).transpose()
v = np.array([1,2])

a = m.dot(v)
print(a)
# Out:
# [2. 3.]

# %%
i_d = np.array([1,0])
j_d = np.array([2,2])

trans = np.array([i_d,j_d]).transpose()

det = det(trans)

#ans = trans.dot(trans)
print(det)
# Out:
# 2.0

# %%
# Linear Depenet cause both point in the same direction and we can get (2,6) by scaling (1,3)
