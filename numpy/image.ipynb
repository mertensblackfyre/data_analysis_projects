# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Load any image
img = Image.open("l.jpg")
img_array = np.array(img)


R = img_array[:,:,0] / 255
G = img_array[:,:,1] / 255
B = img_array[:,:,2] / 255
C = R + G + B

gre = np.where(C > 0.0031308,1.055 * (C ** (1/2.4)) - 0.055, C * 12.92)
img_array[:,:,0] = gre * 100
img_array[:,:,1] = gre * 100
img_array[:,:,2] = gre * 100
#plt.imshow(img_array)

# %%
a = np.fliplr(img_array)
b = np.flipud(img_array)
c = np.rot90(img_array,4,(1,2))
#plt.imshow(c)

# %%
q = img_array
h, w = img_array.shape[:2]
x = q[h//2:3*h//4,w//2:3*w//4]
